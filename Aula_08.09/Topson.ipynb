# %%
#Inportando bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime #importa a biblioteca para puxar o tempo

# %%
#Cria a variável df para guardar o data frame
df = pd.read_csv("https://raw.githubusercontent.com/danielvieira95/Inteligencia_Artificial_2025/refs/heads/main/bases_de_dados/monitoramento_tempo.csv")

# %%
df["data"] = pd.to_datetime(df['data']) #Conversão da coluna data para datetime 64

# %%
df.head()
# Out:
#    temperatura  pressão  humidade  direção do vento  velocidade do vento  \
# 0   282.080000   1024.0      81.0               0.0                  0.0
# 1   282.080000   1024.0      81.0               0.0                  0.0
# 2   282.083252   1024.0      80.0               4.0                  0.0
# 3   282.091866   1024.0      80.0              18.0                  0.0
# 4   282.100481   1024.0      80.0              31.0                  0.0
#
#   dia_da_semana                data
# 0       Domingo 2012-10-01 12:00:00
# 1       Domingo 2012-10-01 13:00:00
# 2       Domingo 2012-10-01 14:00:00
# 3       Domingo 2012-10-01 15:00:00
# 4       Domingo 2012-10-01 16:00:00

# %%
#Gráfico Umidade x ano




#Anotações
#x1 = df['data'][df['humidade'].idxmax()] # armazena a posição em x1
#y1 = max(df['humidade']) # armazena em y1 o valor da temperatura
#x2 = x1=df['data'][df['humidade'].idxmax()-100]
##y2 = max(df['humidade'])-5 # armazena a posição em y2
#eixo.annotate('Máximo',xy=(x1,y1),fontsize=20,xytext=(x2,y2),arrowprops=dict(facecolor='k')) #Anota no gráfico

#Valor mínimo
#x1 = df['data'][df['humidade'].idxmin()] # anota o valor minimo
#y1 = min(df['humidade']) # armazena o valor minimo de temperatura
#x2= x1 = df['data'][df['humidade'].idxmin()-100] 
#y2 = min(df['humidade'])+5 
#eixo.annotate('Mínimo',xy=(x1,y1),fontsize=20,xytext=(x2,y2),arrowprops=dict(facecolor='k'))
plt.ylim(0,200)
# Anotação do valor máximo
x1 = df['data'][df['humidade'].idxmax()]  # posição em X
y1 = max(df['humidade'])                   # valor máximo
x2 = df['data'][df['humidade'].idxmax()-7000] if df['humidade'].idxmax() > 7000 else df['data'][0]
y2 = max(df['humidade']) - 5               # desloca o texto para cima
eixo.annotate('Máximo', xy=(x1, y1), fontsize=20,
              xytext=(x2, y2), arrowprops=dict(facecolor='k'))

# Anotação do valor mínimo
x1 = df['data'][df['humidade'].idxmin()]  # posição em X
y1 = min(df['humidade'])                   # valor mínimo
x2 = df['data'][df['humidade'].idxmin()-7000] if df['humidade'].idxmin() > 7000 else df['data'][0]
y2 = min(df['humidade']) + 5               # desloca o texto para cima
eixo.annotate('Mínimo', xy=(x1, y1), fontsize=20,
xytext=(x2, y2), arrowprops=dict(facecolor='k'))
# Out:
# C:\Users\luizg\AppData\Local\Temp\ipykernel_24280\1682894268.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   eixo.legend() # exibe a legenda
# Text(2012-10-01 12:00:00, 15.0, 'Mínimo')

# %%
fig = plt.figure(figsize=(12,5))
eixo = fig.add_axes([0,0,1,1]) # cria os eixos da figura
eixo.plot(df['data'],df['humidade'],color='b') # plota o gráfico
eixo.grid(True) # ativa a grade do gráfico
#definindo o período do grafico
eixo.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1)) # define o período do grafico
eixo.set_title('Umidade X Ano',fontsize=25,pad=20) #titulo do grafico
eixo.set_xlabel('Ano',fontsize=20) # titulo do eixo x
eixo.set_ylabel('Umidade',fontsize=20) # titulo do eixo y
eixo.legend() # exibe a legenda

x1 = df['data'][df['humidade'].idxmax()]  # posição em X
y1 = max(df['humidade'])                   # valor máximo
x2 = df['data'][df['humidade'].idxmax()-60]
y2 = max(df['humidade']) - 5               # desloca o texto para cima
eixo.annotate('Máximo', xy=(x1, y1), fontsize=20,
              xytext=(x2, y2), arrowprops=dict(facecolor='k'))

# Anotação do valor mínimo
x1 = df['data'][df['humidade'].idxmin()]  # posição em X
y1 = min(df['humidade'])                   # valor mínimo
x2 = df['data'][df['humidade'].idxmin()-60] 
y2 = min(df['humidade']) + 5               # desloca o texto para cima
eixo.annotate('Mínimo', xy=(x1, y1), fontsize=20,
xytext=(x2, y2), arrowprops=dict(facecolor='k'))
# Out:
# C:\Users\luizg\AppData\Local\Temp\ipykernel_24280\3358510.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   eixo.legend() # exibe a legenda
# Text(2012-10-09 04:00:00, 15.0, 'Mínimo')

# %%
#Gráfico Velocidade do vento x Ano

fig = plt.figure(figsize=(10,3))
eixo = fig.add_axes([0,0,1,1]) # cria os eixos da figura
eixo.plot(df['data'],df['velocidade do vento'],color='b') # plota o gráfico
eixo.grid(True) # ativa a grade do gráfico
#definindo o período do grafico
eixo.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1)) # define o período do grafico
eixo.set_title('Velocidade do vento x Ano',fontsize=30,pad=20) #titulo do grafico
eixo.set_xlabel('Ano',fontsize=15) # titulo do eixo x
eixo.set_ylabel('Velocidade do vento',fontsize=15) # titulo do eixo y
eixo.legend() # exibe a legenda
# Out:
# C:\Users\luizg\AppData\Local\Temp\ipykernel_24280\3191347602.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   eixo.legend() # exibe a legenda
